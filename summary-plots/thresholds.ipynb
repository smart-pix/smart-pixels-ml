# %%
thresholds = {}

# %%
# Transformer
thresholds['transformer'] = {}

# Conv2D
thresholds['transformer']['mu'] = [400,600,800]
thresholds['transformer']['sigma'] = [40,60,80]

# %%
# Max
thresholds['max_conv2d'] = {80.31 356.33,1187.92}

# Conv2D
thresholds['max_conv2d']['mu'] = [400,600,800]
thresholds['max_conv2d']['sigma'] = [40,60,80]

# %%
# Full
thresholds['full_conv2d'] = {161.45,512.57,1490.10}
thresholds['full_conv1d'] = {}
thresholds['full_mlp'] = {170.99,573.19,1491.02}

# Conv2D
thresholds['full_conv2d']['mu'] = [400,600,800]
thresholds['full_conv2d']['sigma'] = [40,60,80]
# Conv1D
thresholds['full_conv1d']['mu'] = [400,600,800]
thresholds['full_conv1d']['sigma'] = [40,60,80]
# MLP
thresholds['full_mlp']['mu'] = [400,600,800]
thresholds['full_mlp']['sigma'] = [40,60,80]

# %%
# Slim
thresholds['slim_conv2d'] = {}
thresholds['slim_conv1d'] = {}
thresholds['slim_mlp'] = {80.31,438.53,1140.55}

# Conv2D
thresholds['slim_conv2d']['mu'] = [400,600,800]
thresholds['slim_conv2d']['sigma'] = [40,60,80]
# Conv1D
thresholds['slim_conv1d']['mu'] = [400,600,800]
thresholds['slim_conv1d']['sigma'] = [40,60,80]
# MLP
thresholds['slim_mlp']['mu'] = [400,600,800]
thresholds['slim_mlp']['sigma'] = [40,60,80]

# %%
import json
with open("thresholds.json", "w") as json_file:
    json.dump(thresholds, json_file, indent=4)
