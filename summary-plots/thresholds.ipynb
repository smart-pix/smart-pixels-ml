# %%
thresholds = {}

# %%
# Transformer
thresholds['transformer'] = {}

# Conv2D
thresholds['transformer']['mu'] = [249.2,674,1673.6]
thresholds['transformer']['sigma'] = [8,14.1,38.9]

# %%
# Max
thresholds['max_conv2d'] = {}

# Conv2D
thresholds['max_conv2d']['mu'] = [340.4,692.6,1651.1]
thresholds['max_conv2d']['sigma'] = [40,60,80]

# %%
# Full
thresholds['full_conv2d'] = {}
thresholds['full_conv1d'] = {}
thresholds['full_mlp'] = {}

# Conv2D
thresholds['full_conv2d']['mu'] = [331.6,694.5,1681]
thresholds['full_conv2d']['sigma'] = [40,60,80]
# Conv1D
thresholds['full_conv1d']['mu'] = [307.1,716.3,1626.5]
thresholds['full_conv1d']['sigma'] = [40,60,80]
# MLP
thresholds['full_mlp']['mu'] = [323.9,685.8,1659.9]
thresholds['full_mlp']['sigma'] = [40,60,80]

# %%
# Slim
thresholds['slim_conv2d'] = {}
thresholds['slim_conv1d'] = {}
thresholds['slim_mlp'] = {}

# Conv2D
thresholds['slim_conv2d']['mu'] = [266.5,465.5,983.0]
thresholds['slim_conv2d']['sigma'] = [40,60,80]
# Conv1D
thresholds['slim_conv1d']['mu'] = [299.43,529.4,1221.6]
thresholds['slim_conv1d']['sigma'] = [40,60,80]
# MLP
thresholds['slim_mlp']['mu'] = [298.5,592.7,1479.9]
thresholds['slim_mlp']['sigma'] = [40,60,80]

# %%
import json
with open("thresholds.json", "w") as json_file:
    json.dump(thresholds, json_file, indent=4)
